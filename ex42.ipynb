# %%
## Animal is-a objeto olhe para o crédito extra
class Animal(object):
    pass

## ??
class Cachorro(Animal):

    def __init__(self, nome):
        ## ??
        self.nome = nome

## ??
class Gato(Animal):

    def __init__(self, nome):
        ## ??
        self.nome = nome

## ??
class Pessoa(object):

    def __init__(self, nome):
        ## ??
        self.name = nome

        ## Person has-a pet of some kind
        self.pet = None

class Empregado(Pessoa):

    def __init__(self, nome, salario):
        ## ?? hmm what is this strange magic?
        super(Empregado, self).__init__(nome)
        
        self.salario = salario

class Peixe(object):
    pass

class Salmao(Peixe):
    pass

class Halibut(Peixe):
    pass


## rover is-a cachorro
rover = Cachorro("Rover")

satan = Gato("Satan")

mary = Pessoa("Mary")

mary.pet = satan

frank = Empregado("Frank", 120000)

frank.pet = rover

## ??
flipper = Peixe()

## ??
crouse = Salmao()

## ??
harry = Halibut()
